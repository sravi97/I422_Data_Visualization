# %% [markdown]
# # Module 10: Logscale

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import scipy.stats as ss
import vega_datasets
# %matplotlib inline

# %% [markdown]
# ## Ratio and logarithm
#
# If you use linear scale to visualize ratios, it can be quite misleading.
#
# Let's first create some ratios.

# %%
x = np.array([1,    1,   1,  1, 10, 100, 1000])
y = np.array([1000, 100, 10, 1, 1,  1,   1   ])
ratio = x/y
print(ratio)
# Out:
# [1.e-03 1.e-02 1.e-01 1.e+00 1.e+01 1.e+02 1.e+03]

# %% [markdown]
# **Q: Plot on the linear scale using the [`scatter()`](http://matplotlib.org/examples/shapes_and_collections/scatter_demo.html) function. Also draw a horizontal line at ratio=1 for a reference. **

# %%
# Implement
plt.scatter([0,1,2,3,4,5,6], ratio)
plt.axhline(y=1, color='gray')

# %% [markdown]
# **Q: Explain what's bad about this plot.**

# %%
The graph is logarithmic.

# %% [markdown]
# **Q: Can you fix it? **

# %%
# Implement

# %% [markdown]
# ## Log-binning
#
# Let's first see what happens if we do not use the log scale for a dataset with a heavy tail.
#
# **Q: Load the movie dataset from `vega_datasets` and remove the NaN rows based on the following three columns: `IMDB_Rating`, `IMDB_Votes`, `Rotten_Tomatoes_Rating`. **

# %%
# Implement
import vega_datasets
movies = vega_datasets.data.movies()
movies.dropna(subset=['IMDB_Rating', 'IMDB_Votes', 'Rotten_Tomatoes_Rating'])
# Out:
#              Creative_Type            Director              Distributor  \
# 4     Contemporary Fiction                None                  Trimark
# 8                     None      Roman Polanski                     None
# 9                     None                None                     None
# 10                    None                None                     None
# 11                    None                None            Sony Pictures
# 12                    None                None                Universal
# 14                    None                None                     None
# 18                    None                None                     None
# 21      Historical Fiction                None            Sony/Columbia
# 22      Historical Fiction    Steven Spielberg                Universal
# 24         Science Fiction     Stanley Kubrick                     None
# 28    Contemporary Fiction      Michael Polish   Sony Pictures Classics
# 31    Contemporary Fiction                None     Walt Disney Pictures
# 33                    None                None             Warner Bros.
# 34    Contemporary Fiction    Robert Rodriguez                  Miramax
# 35    Contemporary Fiction           Alan Alda                Universal
# 36    Contemporary Fiction         Mike Newell                 Gramercy
# 37                    None                None              Truly Indie
# 38                    None                None                     None
# 41         Science Fiction       James Cameron         20th Century Fox
# 42    Contemporary Fiction                None  Lorimar Motion Pictures
# 43    Contemporary Fiction         Tom Shadyac             Warner Bros.
# 47                    None                None                      MGM
# 48                    None                None       RKO Radio Pictures
# 50      Historical Fiction          John Wayne           United Artists
# 52           Dramatization      Frank Marshall     Walt Disney Pictures
# 54                    None        George Lucas                Universal
# 56    Contemporary Fiction          Rob Reiner            Sony Pictures
# 57                    None         Woody Allen                      MGM
# 59      Historical Fiction     Stephen Sommers     Walt Disney Pictures
# ...                    ...                 ...                      ...
# 3156  Contemporary Fiction        Mike Nichols            Sony Pictures
# 3158  Contemporary Fiction    Darren Aronofsky          Fox Searchlight
# 3159  Contemporary Fiction          Kevin Bray                      MGM
# 3160         Dramatization        Oliver Stone       Paramount Pictures
# 3161  Contemporary Fiction                None                Universal
# 3162  Contemporary Fiction      Gore Verbinski       Paramount Pictures
# 3163       Science Fiction                None       Paramount Pictures
# 3164  Contemporary Fiction        Dominic Sena             Warner Bros.
# 3165  Contemporary Fiction        Frank Coraci     Walt Disney Pictures
# 3166  Contemporary Fiction                None         20th Century Fox
# 3167  Contemporary Fiction        Nancy Meyers       Paramount Pictures
# 3168  Contemporary Fiction                None                  Artisan
# 3171         Dramatization         Tom Vaughan                CBS Films
# 3172            Super Hero        Bryan Singer         20th Century Fox
# 3174            Super Hero        Brett Ratner         20th Century Fox
# 3176  Contemporary Fiction  Sylvester Stallone                Lionsgate
# 3178                  None          James Gray                  Miramax
# 3180  Contemporary Fiction                None        Paramount Vantage
# 3181    Historical Fiction        Harold Ramis            Sony Pictures
# 3183  Contemporary Fiction         Peyton Reed             Warner Bros.
# 3184  Contemporary Fiction           John Dahl                IFC Films
# 3186  Contemporary Fiction         Nora Ephron             Warner Bros.
# 3191         Dramatization                None               Apparition
# 3193  Contemporary Fiction                None            Sony Pictures
# 3194  Contemporary Fiction         Ben Stiller       Paramount Pictures
# 3195               Fantasy     Ruben Fleischer            Sony Pictures
# 3196  Contemporary Fiction         Kevin Smith            Weinstein Co.
# 3198            Super Hero        Peter Hewitt            Sony Pictures
# 3199    Historical Fiction     Martin Campbell            Sony Pictures
# 3200    Historical Fiction     Martin Campbell            Sony Pictures
#
#       IMDB_Rating  IMDB_Votes MPAA_Rating        Major_Genre  \
# 4             3.4       165.0           R              Drama
# 8             5.8      3275.0           R               None
# 9             7.0      2906.0        None               None
# 10            7.0      4035.0        None               None
# 11            7.5      9111.0        None            Musical
# 12            8.4     82786.0        None               None
# 14            6.8      1532.0        None               None
# 18            2.5      1677.0        None               None
# 21            7.0      4099.0          PG              Drama
# 22            5.6     13364.0        None             Comedy
# 24            8.4    160342.0        None               None
# 28            7.1      2810.0           R              Drama
# 31            3.2      3107.0          PG             Action
# 33            7.7      4263.0        None            Musical
# 34            6.4     34328.0           R             Comedy
# 35            7.0      1814.0        None             Comedy
# 36            7.1     39003.0           R    Romantic Comedy
# 37            7.4       439.0   Not Rated               None
# 38            6.8      2104.0        None              Drama
# 41            7.6     51018.0       PG-13             Action
# 42            4.6      3856.0        None             Action
# 43            6.6     63543.0       PG-13             Comedy
# 47            7.1      1326.0        None            Musical
# 48            6.7     63458.0        None            Musical
# 50            5.9     10063.0       PG-13            Western
# 52            3.2       124.0           R          Adventure
# 54            7.6     30952.0        None             Comedy
# 56            6.8     22780.0       PG-13    Romantic Comedy
# 57            8.2     65406.0        None             Comedy
# 59            5.8      3095.0          PG          Adventure
# ...           ...         ...         ...                ...
# 3156          5.4      5304.0           R             Comedy
# 3158          8.2     93301.0           R              Drama
# 3159          6.0     20517.0       PG-13             Action
# 3160          6.2     34341.0       PG-13              Drama
# 3161          3.7       959.0           R  Thriller/Suspense
# 3162          6.9     35394.0           R              Drama
# 3163          6.3     40281.0          PG          Adventure
# 3164          5.3     10044.0           R  Thriller/Suspense
# 3165          5.7     43251.0       PG-13             Comedy
# 3166          5.8       119.0           R             Horror
# 3167          6.3     54525.0       PG-13    Romantic Comedy
# 3168          6.5     17513.0           R             Action
# 3171          6.4      3770.0          PG              Drama
# 3172          7.4    120706.0       PG-13             Action
# 3174          6.9    109125.0       PG-13             Action
# 3176          7.1     42427.0        None             Action
# 3178          6.3      8784.0           R              Drama
# 3180          7.7     14261.0           R              Drama
# 3181          5.0     23091.0       PG-13             Comedy
# 3183          7.0     62150.0       PG-13             Comedy
# 3184          6.7      9498.0           R       Black Comedy
# 3186          6.2     52587.0          PG              Drama
# 3191          7.2      8408.0          PG              Drama
# 3193          6.8      8489.0           R             Comedy
# 3194          6.4     69296.0       PG-13             Comedy
# 3195          7.8     81629.0           R             Comedy
# 3196          7.0     55687.0           R             Comedy
# 3198          3.4      7424.0          PG          Adventure
# 3199          5.7     21161.0          PG          Adventure
# 3200          6.7      4789.0       PG-13          Adventure
#
#       Production_Budget Release_Date  Rotten_Tomatoes_Rating  \
# 4             1000000.0     9-Oct-98                    62.0
# 8            40000000.0     1-Jul-86                    25.0
# 9             6000000.0    31-Dec-46                    86.0
# 10            1000000.0     7-Oct-63                    81.0
# 11           10000000.0    11-Dec-68                    84.0
# 12            2000000.0    25-Dec-62                    97.0
# 14             100000.0     1-Mar-87                    87.0
# 18           13500000.0     5-Oct-56                    90.0
# 21            4000000.0     9-Nov-72                    57.0
# 22           32000000.0    14-Dec-79                    33.0
# 24           10500000.0     2-Apr-68                    96.0
# 28             500000.0    30-Jul-99                    77.0
# 31           20000000.0     6-May-94                    17.0
# 33             439000.0     9-Mar-33                    95.0
# 34            4000000.0    25-Dec-95                    14.0
# 35            6500000.0    22-May-81                    71.0
# 36            4500000.0     9-Mar-94                    96.0
# 37             350000.0    18-Oct-06                    97.0
# 38           17000000.0   1963-01-01                    57.0
# 41           70000000.0     9-Aug-89                    88.0
# 42            7000000.0    12-Feb-88                    10.0
# 43           12000000.0     4-Feb-94                    49.0
# 47            3768785.0    17-May-50                   100.0
# 48            3000000.0    28-Jul-51                    20.0
# 50           12000000.0    24-Oct-60                    54.0
# 52           32000000.0    15-Jan-93                    71.0
# 54             777000.0    11-Aug-73                    97.0
# 56           62000000.0    17-Nov-95                    90.0
# 57            4000000.0    20-Apr-77                    98.0
# 59            6500000.0     2-Apr-93                    62.0
# ...                 ...          ...                     ...
# 3156         50000000.0     3-Mar-00                    42.0
# 3158          6000000.0    17-Dec-08                    98.0
# 3159         56000000.0     2-Apr-04                    25.0
# 3160         65000000.0     9-Aug-06                    69.0
# 3161         33000000.0     8-Sep-00                    10.0
# 3162         20000000.0    28-Oct-05                    58.0
# 3163         70000000.0    17-Sep-04                    72.0
# 3164         35000000.0    11-Sep-09                     7.0
# 3165         23000000.0     6-Nov-98                    32.0
# 3166         10000000.0    30-May-03                    40.0
# 3167         65000000.0    15-Dec-00                    53.0
# 3168          9000000.0     8-Sep-00                    48.0
# 3171         31000000.0    22-Jan-10                    27.0
# 3172         75000000.0    14-Jul-00                    82.0
# 3174        150000000.0    26-May-06                    57.0
# 3176         82000000.0    13-Aug-10                    40.0
# 3178         20000000.0    20-Oct-00                    64.0
# 3180          1200000.0    10-Nov-00                    95.0
# 3181         60000000.0    19-Jun-09                    14.0
# 3183         50000000.0    19-Dec-08                    43.0
# 3184          4000000.0    22-Jun-07                    78.0
# 3186         65000000.0    18-Dec-98                    68.0
# 3191         35000000.0    18-Dec-09                    76.0
# 3193          5000000.0    30-Jan-98                    66.0
# 3194         28000000.0    28-Sep-01                    62.0
# 3195         23600000.0     2-Oct-09                    89.0
# 3196         24000000.0    31-Oct-08                    65.0
# 3198         35000000.0    11-Aug-06                     3.0
# 3199         80000000.0    28-Oct-05                    26.0
# 3200         65000000.0    17-Jul-98                    82.0
#
#       Running_Time_min                        Source  \
# 4                  NaN           Original Screenplay
# 8                  NaN                          None
# 9                  NaN                          None
# 10                 NaN                          None
# 11                 NaN                          None
# 12                 NaN                          None
# 14                 NaN                          None
# 18                 NaN                          None
# 21                 NaN                 Based on Play
# 22                 NaN           Original Screenplay
# 24                 NaN           Original Screenplay
# 28                 NaN           Original Screenplay
# 31                 NaN           Original Screenplay
# 33                 NaN     Based on Book/Short Story
# 34                 NaN           Original Screenplay
# 35                 NaN           Original Screenplay
# 36                 NaN           Original Screenplay
# 37                 NaN                          None
# 38                 NaN           Original Screenplay
# 41                 NaN           Original Screenplay
# 42                 NaN           Original Screenplay
# 43                 NaN           Original Screenplay
# 47                 NaN     Based on Book/Short Story
# 48                 NaN     Based on Book/Short Story
# 50                 NaN           Original Screenplay
# 52                 NaN     Based on Book/Short Story
# 54                 NaN           Original Screenplay
# 56                 NaN           Original Screenplay
# 57                 NaN           Original Screenplay
# 59                 NaN     Based on Book/Short Story
# ...                ...                           ...
# 3156               NaN           Original Screenplay
# 3158             109.0           Original Screenplay
# 3159              87.0                        Remake
# 3160               NaN     Based on Real Life Events
# 3161              97.0           Original Screenplay
# 3162               NaN           Original Screenplay
# 3163             106.0           Original Screenplay
# 3164               NaN  Based on Comic/Graphic Novel
# 3165              86.0           Original Screenplay
# 3166               NaN           Original Screenplay
# 3167             127.0           Original Screenplay
# 3168               NaN           Original Screenplay
# 3171               NaN     Based on Real Life Events
# 3172             104.0  Based on Comic/Graphic Novel
# 3174               NaN  Based on Comic/Graphic Novel
# 3176             103.0           Original Screenplay
# 3178               NaN                          None
# 3180               NaN           Original Screenplay
# 3181              97.0           Original Screenplay
# 3183             104.0     Based on Book/Short Story
# 3184              92.0           Original Screenplay
# 3186             119.0                 Based on Play
# 3191               NaN     Based on Real Life Events
# 3193               NaN           Original Screenplay
# 3194              89.0           Original Screenplay
# 3195              87.0           Original Screenplay
# 3196             101.0           Original Screenplay
# 3198               NaN  Based on Comic/Graphic Novel
# 3199             129.0                        Remake
# 3200             136.0                        Remake
#
#                                       Title  US_DVD_Sales     US_Gross  \
# 4                                      Slam           NaN    1009819.0
# 8                                   Pirates           NaN    1641825.0
# 9                           Duel in the Sun           NaN   20400000.0
# 10                                Tom Jones           NaN   37600000.0
# 11                                  Oliver!           NaN   37402877.0
# 12                    To Kill A Mockingbird           NaN   13129846.0
# 14                        Hollywood Shuffle           NaN    5228617.0
# 18                     The Ten Commandments           NaN   80000000.0
# 21                                     1776           NaN          0.0
# 22                                     1941           NaN   34175000.0
# 24                    2001: A Space Odyssey           NaN   56700000.0
# 28                         Twin Falls Idaho           NaN     985341.0
# 31                       3 Ninjas Kick Back           NaN   11744960.0
# 33                              42nd Street           NaN    2300000.0
# 34                               Four Rooms           NaN    4301000.0
# 35                         The Four Seasons           NaN   42488161.0
# 36              Four Weddings and a Funeral           NaN   52700832.0
# 37                          51 Birch Street           NaN      84689.0
# 38                        55 Days at Peking           NaN   10000000.0
# 41                                The Abyss           NaN   54243125.0
# 42                           Action Jackson           NaN   20257000.0
# 43               Ace Ventura: Pet Detective           NaN   72217396.0
# 47                       Annie Get Your Gun           NaN    8000000.0
# 48                      Alice in Wonderland           NaN          0.0
# 50                                The Alamo           NaN    7900000.0
# 52                                    Alive           NaN   36299670.0
# 54                        American Graffiti           NaN  115000000.0
# 56                   The American President           NaN   60022813.0
# 57                               Annie Hall           NaN   38251425.0
# 59              The Adventures of Huck Finn           NaN   24103594.0
# ...                                     ...           ...          ...
# 3156              What Planet Are You From?           NaN    6291602.0
# 3158                           The Wrestler    11912450.0   26236603.0
# 3159                           Walking Tall           NaN   46213824.0
# 3160                     World Trade Center    36877248.0   70278893.0
# 3161                            The Watcher           NaN   28946615.0
# 3162                        The Weather Man    16632857.0   12482775.0
# 3163  Sky Captain and the World of Tomorrow           NaN   37760080.0
# 3164                               Whiteout     3231673.0   10275638.0
# 3165                           The Waterboy           NaN  161491646.0
# 3166                             Wrong Turn           NaN   15417771.0
# 3167                        What Women Want           NaN  182805123.0
# 3168                     The Way of the Gun           NaN    6047856.0
# 3171                 Extraordinary Measures     5267433.0   12482741.0
# 3172                                  X-Men           NaN  157299717.0
# 3174                  X-Men: The Last Stand   103555667.0  234362462.0
# 3176                        The Expendables           NaN  101384023.0
# 3178                              The Yards           NaN     882710.0
# 3180                    You Can Count on Me           NaN    9180275.0
# 3181                               Year One    14813995.0   43337279.0
# 3183                                Yes Man    26601131.0   97690976.0
# 3184                            You Kill Me           NaN    2426851.0
# 3186                        You've Got Mail           NaN  115821495.0
# 3191                     The Young Victoria     3273039.0   11001272.0
# 3193                            Zero Effect           NaN    2080693.0
# 3194                              Zoolander           NaN   45172250.0
# 3195                             Zombieland    28281155.0   75590286.0
# 3196             Zack and Miri Make a Porno    21240321.0   31452765.0
# 3198                                   Zoom     6679409.0   11989328.0
# 3199                    The Legend of Zorro           NaN   45575336.0
# 3200                      The Mask of Zorro           NaN   93828745.0
#
#       Worldwide_Gross
# 4           1087521.0
# 8           6341825.0
# 9          20400000.0
# 10         37600000.0
# 11         37402877.0
# 12         13129846.0
# 14          5228617.0
# 18         80000000.0
# 21                0.0
# 22         94875000.0
# 24         68700000.0
# 28          1027228.0
# 31         11744960.0
# 33          2300000.0
# 34          4301000.0
# 35         42488161.0
# 36        242895809.0
# 37            84689.0
# 38         10000000.0
# 41         54243125.0
# 42         20257000.0
# 43        107217396.0
# 47          8000000.0
# 48                0.0
# 50          7900000.0
# 52         36299670.0
# 54        140000000.0
# 56        107822813.0
# 57         38251425.0
# 59         24103594.0
# ...               ...
# 3156        6291602.0
# 3158       43236603.0
# 3159       47313824.0
# 3160      163278893.0
# 3161       47267829.0
# 3162       15466961.0
# 3163       49730854.0
# 3164       12254746.0
# 3165      190191646.0
# 3166       28649556.0
# 3167      372100000.0
# 3168       13061935.0
# 3171       12697741.0
# 3172      334627820.0
# 3174      459359555.0
# 3176      240484023.0
# 3178        2282710.0
# 3180       11005992.0
# 3181       57604723.0
# 3183      225990976.0
# 3184        2426851.0
# 3186      250800000.0
# 3191       11001272.0
# 3193        2080693.0
# 3194       60780981.0
# 3195       98690286.0
# 3196       36851125.0
# 3198       12506188.0
# 3199      141475336.0
# 3200      233700000.0
#
# [2260 rows x 16 columns]

# %% [markdown]
# If you simply call `hist()` method with a dataframe object, it identifies all the numeric columns and draw a histogram for each.
#
# **Q: draw all possible histograms of the movie dataframe. Adjust the size of the plots if needed. **

# %%
movies.hist(figsize=(16,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a226cb5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2298ba20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22c450b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a22c6a748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22c92dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22c92e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a22cebb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22d1e208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22d45898>]],
#       dtype=object)

# %% [markdown]
# As we can see, a majority of the columns are not normally distributed. In particular, if you look at the worldwide gross variable, you only see a couple of meaningful data from the histogram. Is this a problem of resolution? How about increasing the number of bins?
#
# **Q: Play with the number of bins, and then increase the number of bins to 200. **

# %%
# Implement
movies.hist(column = 'Worldwide_Gross', bins = 200)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a237f4278>]],
#       dtype=object)

# %% [markdown]
# Maybe a bit more useful, but it doesn't tell anything about the data distribution above certain point.
#
# **Q: How about changing the vertical scale to logarithmic scale?**

# %%
# Implement
movies.hist(column = 'Worldwide_Gross', bins = 200)
plt.semilogy()
# Out:
# []

# %% [markdown]
# Now, let's try log-bin. Recall that when plotting histgrams we can specify the edges of bins through the `bins` parameter. For example, we can specify the edges of bins to [1, 2, 3, ... , 10] as follows.

# %%
movies.IMDB_Rating.hist(bins=range(0,11))

# %% [markdown]
# Here, we can specify the edges of bins in a similar way. Instead of specifying on the linear scale, we do it on the log space. Some useful resources:
#
# * [Google query: python log-bin](https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=python+log-bin&pws=0)
# * [numpy.logspace](http://docs.scipy.org/doc/numpy/reference/generated/numpy.logspace.html)
# * [numpy.linspace vs numpy.logspace](http://stackoverflow.com/questions/31480033/difference-in-output-between-numpy-linspace-and-numpy-logspace)
#
# Hint: since $10^{\text{start}} = \text{min(Worldwide_Gross)}$, $\text{start} = \log_{10}(\text{min(Worldwide_Gross)})$

# %%
min(movies.Worldwide_Gross)
# Out:
# 0.0

# %% [markdown]
# Because there seems to be movie(s) that made $0, and because log(0) is undefined & log(1) = 0, let's add 1 to the variable.

# %%
movies.Worldwide_Gross = movies.Worldwide_Gross+1.0

# %% [markdown]
# **Q: now create logarithmic bins. Create 20 bins from the minimum value to the maximum value.**

# %%
# Implement
movies.hist(column = 'Worldwide_Gross', bins = 20)
plt.semilogy()
plt.semilogx()
# Out:
# []

# %% [markdown]
# Now we can plot a histgram with log-bin. Set both axis to be log-scale.

# %%
# Implement
# Implement
movies.hist(column = 'Worldwide_Gross', bins = 20)
plt.semilogy()
plt.semilogx()
# Out:
# Text(0,0.5,'Frequency')

# %% [markdown]
# What is going on? Is this the right plot?
#
# **Q: explain and fix**

# %% [markdown]
# **Q: Can you explain the plot? Why are there gaps?**

# %% [markdown]
# ## CCDF
#
# CCDF is a nice alternative to examine distributions with heavy tails. The idea is same as CDF, but the direction of aggregation is opposite. We have done CDF before. It's just a small change to that code.
#
# **Q: Draw a CCDF in log-log scale**

# %%
# implement

# %% [markdown]
# We can also try in semilog scale (only one axis is in a log-scale), where the horizontal axis is linear.
#
# **Q: Draw a CCDF in semilog scale**

# %%
# Implement

# %% [markdown]
# A straight line in semilog scale means exponential decay (cf. a straight line in log-log scale means power-law decay). So it seems like the amount of money a movie makes across the world follows *roughly* an exponential distribution, while there are some outliers that make insane amount of money.
#
# **Q: Which is the most successful movie in our dataset?**
#
# You can use the following
#
# - `idxmax()`: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.idxmax.html
# - `loc`: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.loc.html or `iloc`: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.iloc.html
#
# Which one should you use, `loc` or `iloc`? How are they different from each other?

# %%
# Implement
